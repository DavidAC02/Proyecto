# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("Pulpo.png",cv2.IMREAD_GRAYSCALE)
#gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.imread("Pulpo.png",cv2.IMREAD_GRAYSCALE)

# %%
gradX = cv2.Sobel(gray, cv2.CV_32F, dx=1, dy=0, ksize=-1)
gradY = cv2.Sobel(gray, cv2.CV_32F, dx=0, dy=1, ksize=-1)

# %%
# subtract the y-gradient from the x-gradient
gradient = cv2.subtract(gradX, gradY)
gradient = cv2.convertScaleAbs(gradient)

# %%
blurred = cv2.blur(gradient, (9, 9))
_, thresh = cv2.threshold(blurred, 90, 255, cv2.THRESH_BINARY)

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (25, 25))
closed = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# %%
closed = cv2.erode(closed, None, iterations=4)
closed = cv2.dilate(closed, None, iterations=4)

# %%
plt.imshow(closed)
cv2.waitKey()
# Out:
# -1

# %%
a=100
c=0
Imagen=closed
while a>2:
    (cntsf, xf) = cv2.findContours(Imagen.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cf = sorted(cntsf, key=cv2.contourArea, reverse=True)[0]
    rectf = cv2.minAreaRect(cf)
    boxf = np.int0(cv2.boxPoints(rectf))
    #imf=cv2.drawContours(image, [boxf], -1, (0, 255, 0), 3)
    #cv2.imshow("Image", Imagen)
    #plt.imshow(image)
    Xsf = [i[0] for i in boxf]
    Ysf = [i[1] for i in boxf]
    x1f = min(Xsf)
    x2f = max(Xsf)
    y1f = min(Ysf)
    y2f = max(Ysf)
    cropImgf= image[y1f:y2f, x1f:x2f]
    #plt.imshow(cropImgf)
    A=str(c)
    cv2.imwrite("imagen"+A+".jpg", cropImgf)
    #HASTA AQUI SE HIZO TODO UNA VEZ
    b=0
    dimensionesf = (closed.shape[0],closed.shape[1])
    arrayf=np.zeros(dimensionesf)
    for i in range(closed.shape[1]):
        for j in range(closed.shape[0]):
            if (x1f < i < x2f and y1f < j < y2f):
                arrayf[j,i]=0
            else:
                arrayf[j,i]=Imagen[j,i]
    for i in range(closed.shape[1]):
        for j in range(closed.shape[0]):
            if (arrayf[j,i]>0):
                b=b+1
    a=(b*100)/(closed.shape[0]*closed.shape[1])
    c=c+1
    Imagen= np.uint8(arrayf)
        #recortar(arrf)

# %%
def recortar(imagen):
    image = cv2.imread(imagen,cv2.IMREAD_GRAYSCALE)
    gradX = cv2.Sobel(image, cv2.CV_32F, dx=1, dy=0, ksize=-1)
    gradY = cv2.Sobel(image, cv2.CV_32F, dx=0, dy=1, ksize=-1)
    gradient = cv2.subtract(gradX, gradY)
    gradient = cv2.convertScaleAbs(gradient)
    blurred = cv2.blur(gradient, (9, 9))
    _, thresh = cv2.threshold(blurred, 90, 255, cv2.THRESH_BINARY)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (25, 25))
    closed = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)
    closed = cv2.erode(closed, None, iterations=4)
    closed = cv2.dilate(closed, None, iterations=4)
    a=100
    c=0
    Imagen=closed
    while a>2:
        (cntsf, xf) = cv2.findContours(Imagen.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cf = sorted(cntsf, key=cv2.contourArea, reverse=True)[0]
        rectf = cv2.minAreaRect(cf)
        boxf = np.int0(cv2.boxPoints(rectf))
        Xsf = [i[0] for i in boxf]
        Ysf = [i[1] for i in boxf]
        x1f = min(Xsf)
        x2f = max(Xsf)
        y1f = min(Ysf)
        y2f = max(Ysf)
        cropImgf= image[y1f:y2f, x1f:x2f]
        #plt.imshow(cropImgf)
        A=str(c)
        cv2.imwrite("imagen"+A+".jpg", cropImgf)
        #HASTA AQUI SE HIZO TODO UNA VEZ
        b=0
        dimensionesf = (closed.shape[0],closed.shape[1])
        arrayf=np.zeros(dimensionesf)
        for i in range(closed.shape[1]):
            for j in range(closed.shape[0]):
                if (x1f < i < x2f and y1f < j < y2f):
                    arrayf[j,i]=0
                else:
                    arrayf[j,i]=Imagen[j,i]
        for i in range(closed.shape[1]):
            for j in range(closed.shape[0]):
                if (arrayf[j,i]>0):
                    b=b+1
        a=(b*100)/(closed.shape[0]*closed.shape[1])
        c=c+1
        Imagen= np.uint8(arrayf)

# %%
recortar("Pulpo.jpg")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-14-4a40f325f5a5> in <module>
# ----> 1 recortar("Pulpo.jpg")
#
# <ipython-input-12-9c7ead0dbb93> in recortar(imagen)
#       1 def recortar(imagen):
#       2     image = cv2.imread(imagen,cv2.IMREAD_GRAYSCALE)
# ----> 3     gradX = cv2.Sobel(image, cv2.CV_32F, dx=1, dy=0, ksize=-1)
#       4     gradY = cv2.Sobel(image, cv2.CV_32F, dx=0, dy=1, ksize=-1)
#       5     gradient = cv2.subtract(gradX, gradY)
#
# error: OpenCV(4.5.4-dev) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\deriv.cpp:419: error: (-215:Assertion failed) !_src.empty() in function 'cv::Sobel'
